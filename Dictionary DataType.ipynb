# %% [markdown]
# # Dictionary

# %% [markdown]
# - Dictionary is a mutable data type in python.
# - A python dictionary is a collection of key and value pairs separated by a colon(:) & enclosed in curly braces{}.
# - Keys must be unique in a dictionary,duplicate values are allowed.

# %% [markdown]
# **Create Dictionary**

# %%
mydict = dict() #empty dictionary
mydict
# Out:
# {}

# %%
mydict = {} # empty dictionary
mydict
# Out:
# {}

# %%
mydict = {1:'one',2:'two',3:'three',4:'four'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict = dict({1:'one',2:'two',3:'three',4:'four'}) # creates dictionary using dict()
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict = {'A':'one' , 'B':'two' , 'C':'three'} # dictionary with character keys
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = {1:'one' , 'A':'two' , 3:'three'} # dictionary with mixed keys
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys() # returns dictionary keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values()  # returns dictionary values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items()  # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one' , 2:'two' , 'A':{'Name':'asif' , 'Age' :20}, 'B':('Bat' , 'cat', 'hat')}
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'asif', 'Age': 20},
#  'B': ('Bat', 'cat', 'hat')}

# %%
keys = {'a','b','c','d'}
mydict3 = dict.fromkeys(keys) # creates a dictionary from a sequence of keys
mydict3
# Out:
# {'d': None, 'b': None, 'c': None, 'a': None}

# %%
keys = {'a','b','c','d'}
value = 10
mydict3 = dict.fromkeys(keys,value)
mydict3
# Out:
# {'d': 10, 'b': 10, 'c': 10, 'a': 10}

# %%
keys = {'a','b','c','d'}
value = [10,20,30]
mydict3 = dict.fromkeys(keys,value)
mydict3
# Out:
# {'d': [10, 20, 30], 'b': [10, 20, 30], 'c': [10, 20, 30], 'a': [10, 20, 30]}

# %%
value.append(40)
mydict3
# Out:
# {'d': [10, 20, 30, 40],
#  'b': [10, 20, 30, 40],
#  'c': [10, 20, 30, 40],
#  'a': [10, 20, 30, 40]}

# %% [markdown]
# **Accessing Items**

# %%
mydict = {1:'one',2:'two',3:'three',4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1]  #access item using key
# Out:
# 'one'

# %%
mydict.get(1) # access item using get() method
# Out:
# 'one'

# %%
mydict1 = {'name':'asif','id':74123,'dob':1991,'job':'Analyst'}
mydict1
# Out:
# {'name': 'asif', 'id': 74123, 'dob': 1991, 'job': 'Analyst'}

# %%
mydict1['name'] # accessing item using key
# Out:
# 'asif'

# %%
mydict1.get('job') # access item using get() method
# Out:
# 'Analyst'

# %% [markdown]
# **Add,Remove & Change Items**

# %%
mydict1
# Out:
# {'name': 'asif', 'id': 74123, 'dob': 1991, 'job': 'Analyst'}

# %%
mydict1['dob'] = 1992  # changing dictionary items
mydict1['name'] = 'Romeo'
mydict1
# Out:
# {'name': 'Romeo', 'id': 74123, 'dob': 1992, 'job': 'Analyst'}

# %%
dict1 = {'dob':1995}
mydict1.update(dict1)
mydict1
# Out:
# {'name': 'Romeo', 'id': 74123, 'dob': 1995, 'job': 'Analyst'}

# %%
mydict1['address'] = 'helsinki'  #adding items in the dictionary
mydict1
# Out:
# {'name': 'Romeo',
#  'id': 74123,
#  'dob': 1995,
#  'job': 'Analyst',
#  'address': 'helsinki'}

# %%
mydict1.pop('job') # removing items in the dictionary using pop method
mydict1
# Out:
# {'name': 'Romeo', 'id': 74123, 'dob': 1995, 'address': 'helsinki'}

# %%
mydict1.popitem()  # a random item is removed
# Out:
# ('address', 'helsinki')

# %%
mydict1
# Out:
# {'name': 'Romeo', 'id': 74123, 'dob': 1995}

# %%
del[mydict1['id']]  # removing item using del method
mydict1
# Out:
# {'name': 'Romeo', 'dob': 1995}

# %%
mydict1.clear()  # delete all items of the dictionary using clear() method
mydict1
# Out:
# {}

# %%
del mydict1  # delete the dictionary object
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 del mydict1  # delete the dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# **Copy Dictionary**

# %%
mydict = {'name':'asif','id':74123,'dob':1991,'job':'Analyst','address':'helsinki'}
mydict
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'helsinki'}

# %%
mydict1 = mydict

# %%
id(mydict), id(mydict1)
# Out:
# (2180132923712, 2180132923712)

# %%
mydict2 = mydict.copy()
mydict2
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'helsinki'}

# %%
id(mydict2)
# Out:
# 2180132245376

# %%
mydict['address'] = 'mumbai'

# %%
mydict
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'mumbai'}

# %%
mydict2
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'helsinki'}

# %% [markdown]
# **Loop through a Dictionary**

# %%
mydict
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'mumbai'}

# %%
for i in mydict:
    print(i,':',mydict[i])  # key & value pair
# Out:
# name : asif
# id : 74123
# dob : 1991
# job : Analyst
# address : mumbai

# %%
for i in mydict:
    print(mydict[i])  # dictionary items
# Out:
# asif
# 74123
# 1991
# Analyst
# mumbai

# %% [markdown]
# **Dictionary Membership**

# %%
mydict1
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'mumbai'}

# %%
'name' in mydict1 # test if a key is in a dictionary or not.
# Out:
# True

# %%
'asif' in mydict1  # membership test can be only done for keys.
# Out:
# False

# %%
'id' in mydict1
# Out:
# True

# %%
'salary' in mydict1
# Out:
# False

# %% [markdown]
# **ALL/ANY**    - The all() method returns:
#
#   -True - if all keys of dictionary are true
#   -False - if any key of the dictionary is false
#
# The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1
# Out:
# {'name': 'asif',
#  'id': 74123,
#  'dob': 1991,
#  'job': 'Analyst',
#  'address': 'mumbai'}

# %%
all(mydict1) # will return true s all values are true(Value 1)
# Out:
# True

# %%
mydict4 ={'one':1,'two': 0}

# %%
all(mydict4)
# Out:
# True
