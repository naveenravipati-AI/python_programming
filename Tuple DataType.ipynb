# %% [markdown]
# # Tuples
# 1.	Tuple is similar to List except that the objects in tuple are immutable which means we cannot change the elements of a tuple once assigned.
# 2.	When we do not want to change the data over time, tuple is a preferred data type.
# 3.	Iterating over the elements of a tuple is faster compared to iterating over a list.

# %% [markdown]
# **Tuple Creation**

# %%
tup1 = ()   #Empty Tuple

# %%
tup2 = (10,20,30) # tuple of integers numbers

# %%
tup3 = (10.33,30.66,60.89)   #tuple of float numbers

# %%
tup4 = ("one","two","three")  #tuple of strings

# %%
tup5 = ('Apple',23,(1,2),(10,2.45,12)) #Nested tuples

# %%
tup6 = ("ant",25,[50,100],[150,90],{"John","David"},(99,22,33))

# %%
len(tup6) #length of list
# Out:
# 6

# %% [markdown]
# **Tuple Indexing**

# %%
tup2[0]  # retrive first element of the tuple
# Out:
# 10

# %%
tup4[0][0]  #Nested indexing - access the first character of the first tuple element
# Out:
# 'o'

# %%
tup4[-1] # last item of the tuple
# Out:
# 'three'

# %%
tup5[-1] #last item of the tuple
# Out:
# (10, 2.45, 12)

# %% [markdown]
# **Tuple Slicing**

# %%
mytuple = ("one","two","three","four","five","six","seven")

# %%
mytuple[0:3]
# Out:
# ('one', 'two', 'three')

# %%
mytuple[:2]
# Out:
# ('one', 'two')

# %%
mytuple[2:4]
# Out:
# ('three', 'four')

# %%
mytuple[-2:]  # returns last two items
# Out:
# ('six', 'seven')

# %%
mytuple[:]  #returns whole tuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %% [markdown]
# **Remove & Change Items**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
del mytuple[0]  #Tuples are immutable which means we can't delete tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 del mytuple[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
mytuple[0] = 1 # Tuples are immuatable which means we can't change them
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 mytuple[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
del mytuple  #Deleting entire tuple object is possible

# %% [markdown]
# **Loop through a Tuple**

# %%
mytuple = ("one","two","three","four","five","six","seven")

# %%
for i in mytuple:
    print(i)
# Out:
# one
# two
# three
# four
# five
# six
# seven

# %%
for i in enumerate(mytuple):
    print(i)
# Out:
# (0, 'one')
# (1, 'two')
# (2, 'three')
# (3, 'four')
# (4, 'five')
# (5, 'six')
# (6, 'seven')

# %% [markdown]
# **Tuple Membership**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
'one' in mytuple #check if 'one' exist in the list
# Out:
# True

# %%
'ten' in mytuple #check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in mytuple:  #check if 'three' exist in tuple
    print('three is present in the tuple')
else:
    print('three is not present in the tuple')
# Out:
# three is present in the tuple

# %%
if 'eleven' in mytuple:  #check if 'eleven' exist in tuple
    print('eleven is present in the tuple')
else:
    print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple

# %% [markdown]
# **Index Position**

# %%
mytuple
# Out:
# ('one', 'two', 'three', 'four', 'five', 'six', 'seven')

# %%
mytuple.index('one')  # Index of first element equal to 'one'
# Out:
# 0

# %%
mytuple.index('five')
# Out:
# 4

# %% [markdown]
# **Sorting**

# %%
mytuple2 = (43,94,67,81,678,56)

# %%
sorted(mytuple2)  # returns a new sorted list and doesn't change original tuple
# Out:
# [43, 56, 67, 81, 94, 678]

# %%
sorted(mytuple2, reverse=True)  #sort in descending order
# Out:
# [678, 94, 81, 67, 56, 43]

# %%
mytuple2  # returns a new sorted list and doesn't change original tuple
# Out:
# (43, 94, 67, 81, 678, 56)
